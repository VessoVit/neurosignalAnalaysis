# %%
import pandas as pd
import scipy as sp
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Data Sources

# %%
dExperiment = pd.read_csv('/home/vagrant/notebooks/data/Experiment.csv')
dTutorial = pd.read_csv('/home/vagrant/notebooks/data/all_tutorial.csv')
dRelax = pd.read_csv('/home/vagrant/notebooks/data/all_Relax_.csv')
dConcent = pd.read_csv('/home/vagrant/notebooks/data/all_ConcentrationAB.csv')

# %% [markdown]
# ### Descriptive Statistics
#
# Each data sets include users' alpha and beta bandwaves after data cleaning and classification. No raw data for privacy reasons.

# %% [markdown]
# All observations

# %%
# dTutorial
# dConcent
# dRelax

# %%
dr1 = dRelax.ix[:,:20]
dc1 = dConcent.ix[:,:20]
ct1 = dTutorial.ix[:,:20]

# %% [markdown]
# ### Tutorial stage.

# %%
ct1.describe()
# Out:
#        user 2 alpha  user 2 beta  user 6 alpha  user 6 beta  user 7 alpha  \
# count   7499.000000  7499.000000   7499.000000  7499.000000   7499.000000
# mean       0.422130     0.287366      0.350194     0.351441      0.351808
# std        0.094317     0.029269      0.058421     0.035064      0.008093
# min        0.269448     0.234130      0.220668     0.269078      0.318956
# 25%        0.371167     0.253455      0.308944     0.335391      0.347469
# 50%        0.420334     0.302027      0.344793     0.346657      0.351861
# 75%        0.451187     0.310546      0.387163     0.367153      0.355295
# max        0.892093     0.335075      0.534613     0.503330      0.382440
#
#        user 7 beta  user 8 alpha  user 8 beta  user 9 alpha  user 9 beta  \
# count  7499.000000   7499.000000  7499.000000   7499.000000  7499.000000
# mean      0.374647      0.333043     0.403010      0.350389     0.353958
# std       0.039878      0.081534     0.140130      0.076132     0.018255
# min       0.272273      0.162359     0.286639      0.000000     0.290429
# 25%       0.349391      0.276964     0.339341      0.301187     0.345094
# 50%       0.369967      0.324079     0.355656      0.337124     0.357006
# 75%       0.404559      0.373278     0.374689      0.402912     0.364621
# max       0.465042      0.560302     0.873689      0.602206     0.409991
#
#        user 12 alpha  user 12 beta  user 13 alpha  user 13 beta  \
# count    7499.000000   7499.000000    7499.000000   7499.000000
# mean        0.360084      0.354274       0.364645      0.354274
# std         0.060687      0.017040       0.116256      0.017040
# min         0.225940      0.307380       0.152452      0.307380
# 25%         0.318610      0.345030       0.292005      0.345030
# 50%         0.349201      0.351482       0.343570      0.351482
# 75%         0.391768      0.358586       0.400452      0.358586
# max         0.587865      0.430900       0.764208      0.430900
#
#        user 16 alpha  user 16 beta  user 17 alpha  user 17 beta      SumBeta  \
# count    7499.000000   7499.000000    7499.000000   7499.000000  7499.000000
# mean        0.353526      0.355939       0.344632      0.348019     3.182929
# std         0.081485      0.028000       0.043003      0.012005     0.184497
# min         0.124802      0.237884       0.241509      0.306730     2.955988
# 25%         0.320505      0.342649       0.319232      0.342221     3.078702
# 50%         0.348585      0.353853       0.342272      0.349068     3.123521
# 75%         0.380726      0.374790       0.370216      0.355436     3.181428
# max         0.688723      0.432521       0.490689      0.377790     3.786777
#
#           SumAlpha
# count  7499.000000
# mean      3.230452
# std       0.190987
# min       2.713474
# 25%       3.119745
# 50%       3.231279
# 75%       3.322371
# max       3.901741

# %%
totalTutorialAlpha = ct1['SumAlpha' ] / 9
totalTutorialBeta = ct1['SumBeta'] / 9
plt.plot(totalTutorialAlpha)
plt.plot(totalTutorialBeta)

# plt.plot(ct1['SumAlpha'])
# plt.plot(ct1['SumBeta'])

# %%
plt.figure(figsize=(12,12))

plt.subplot(4,2,1)
plt.plot(ct1['user 2 alpha'])
plt.plot(ct1['user 2 beta'])
ct_1_am = ct1['user 2 alpha'].mean()
ct_1_bm = ct1['user 2 beta'].mean()

plt.subplot(4,2,2)
plt.plot(ct1['user 6 alpha'])
plt.plot(ct1['user 6 beta'])
ct_2_am = ct1['user 6 alpha'].mean()
ct_2_bm = ct1['user 6 beta'].mean()

plt.subplot(4,2,3)
plt.plot(ct1['user 7 alpha'])
plt.plot(ct1['user 7 beta'])
ct_3_am = ct1['user 7 alpha'].mean()
ct_3_bm = ct1['user 7 beta'].mean()

plt.subplot(4,2,4)
plt.plot(ct1['user 8 alpha'])
plt.plot(ct1['user 8 beta'])
ct_4_am = ct1['user 8 alpha'].mean()
ct_4_bm = ct1['user 8 beta'].mean()

plt.subplot(4,2,5)
plt.plot(ct1['user 9 alpha'])
plt.plot(ct1['user 9 beta'])
ct_5_am = ct1['user 9 alpha'].mean()
ct_5_bm = ct1['user 9 beta'].mean()

plt.subplot(4,2,6)
plt.plot(ct1['user 12 alpha'])
plt.plot(ct1['user 12 beta'])
ct_6_am = ct1['user 12 alpha'].mean()
ct_6_bm = ct1['user 12 beta'].mean()

plt.subplot(4,2,7)
plt.plot(ct1['user 13 alpha'])
plt.plot(ct1['user 13 beta'])
ct_7_am = ct1['user 13 alpha'].mean()
ct_7_bm = ct1['user 13 beta'].mean()

plt.subplot(4,2,8)
plt.plot(ct1['user 16 alpha'])
plt.plot(ct1['user 16 beta'])
ct_8_am = ct1['user 16 alpha'].mean()
ct_8_bm = ct1['user 16 beta'].mean()

# plt.subplot(5,2,9)
# plt.plot(ct1['user 17 alpha'])
# plt.plot(ct1['user 17 beta'])

plt.tight_layout()
plt.show();

# %% [markdown]
# ### Concentration Stage

# %%
dc1.describe()
# Out:
#        user 2 alpha   user 2 beta  user 6 alpha   user 6 beta  user 7 alpha  \
# count  36749.000000  36749.000000  36749.000000  36749.000000  36749.000000
# mean       0.370722      0.264676      0.352083      0.350835      0.349606
# std        0.096436      0.030973      0.087062      0.033516      0.020804
# min       -0.012597      0.177667      0.145453      0.240157      0.229277
# 25%        0.327718      0.243537      0.298296      0.332358      0.341915
# 50%        0.367373      0.250192      0.339546      0.346438      0.349343
# 75%        0.410982      0.294802      0.393691      0.363777      0.353109
# max        0.785272      0.334952      0.823557      0.558415      0.483309
#
#         user 7 beta  user 8 alpha   user 8 beta  user 9 alpha   user 9 beta  \
# count  36749.000000  36749.000000  36749.000000  36749.000000  36749.000000
# mean       0.374400      0.348236      0.348731      0.353859      0.351194
# std        0.108675      0.071119      0.023271      0.080335      0.027189
# min        0.186704      0.152836      0.238819      0.146871      0.270126
# 25%        0.331171      0.300957      0.335962      0.299289      0.336351
# 50%        0.353646      0.343631      0.349058      0.344833      0.349221
# 75%        0.374068      0.389183      0.361116      0.399662      0.361897
# max        0.842983      0.713326      0.470843      0.660951      0.537685
#
#        user 12 alpha  user 12 beta  user 13 alpha  user 13 beta  \
# count   36749.000000  36749.000000   36749.000000  36749.000000
# mean        0.346495      0.348500       0.347973      0.348500
# std         0.087921      0.021136       0.084363      0.021136
# min         0.117128      0.258109       0.128449      0.258109
# 25%         0.284567      0.336450       0.291244      0.336450
# 50%         0.341131      0.347873       0.339165      0.347873
# 75%         0.399334      0.361156       0.394236      0.361156
# max         0.655212      0.426137       0.713201      0.426137
#
#        user 16 alpha  user 16 beta  user 17 alpha  user 17 beta     Sum Alpha  \
# count   36749.000000  36749.000000   36749.000000  36749.000000  36749.000000
# mean        0.347872      0.347250       0.351449      0.350306      3.168295
# std         0.118493      0.035802       0.079839      0.015054      0.245991
# min         0.072216      0.114855       0.126114      0.293787      2.457187
# 25%         0.270845      0.330665       0.297870      0.341833      3.005359
# 50%         0.325201      0.347398       0.345926      0.351283      3.158413
# 75%         0.418286      0.367019       0.390922      0.359273      3.319963
# max         0.947175      0.468273       0.785467      0.410304      4.168465
#
#            Sum Beta
# count  36749.000000
# mean       2.734085
# std        0.129798
# min        2.454805
# 25%        2.652240
# 50%        2.718506
# 75%        2.780047
# max        3.242842

# %%
totalConcentrationAlpha = dc1['Sum Alpha'] / 9;
totalConcentrationBeta = dc1['Sum Beta'] / 9;

plt.plot(totalConcentrationAlpha)
plt.plot(totalConcentrationBeta)

# plt.plot(dc1['Sum Alpha'])
# plt.plot(dc1['Sum Beta'])

# %%
plt.figure(figsize=(12,12))

plt.subplot(4,2,1)
plt.plot(dc1['user 2 alpha'])
plt.plot(dc1['user 2 beta'])
dc_1_am = dc1['user 2 alpha'].mean()
dc_1_bm = dc1['user 2 beta'].mean()

plt.subplot(4,2,2)
plt.plot(dc1['user 6 alpha'])
plt.plot(dc1['user 6 beta'])
dc_2_am = dc1['user 6 alpha'].mean()
dc_2_bm = dc1['user 6 beta'].mean()

plt.subplot(4,2,3)
plt.plot(dc1['user 7 alpha'])
plt.plot(dc1['user 7 beta'])
dc_3_am = dc1['user 7 alpha'].mean()
dc_3_bm = dc1['user 7 beta'].mean()

plt.subplot(4,2,4)
plt.plot(dc1['user 8 alpha'])
plt.plot(dc1['user 8 beta'])
dc_4_am = dc1['user 8 alpha'].mean()
dc_4_bm = dc1['user 8 beta'].mean()

plt.subplot(4,2,5)
plt.plot(dc1['user 9 alpha'])
plt.plot(dc1['user 9 beta'])
dc_5_am = dc1['user 9 alpha'].mean()
dc_5_bm = dc1['user 9 beta'].mean()

plt.subplot(4,2,6)
plt.plot(dc1['user 12 alpha'])
plt.plot(dc1['user 12 beta'])
dc_6_am = dc1['user 12 alpha'].mean()
dc_6_bm = dc1['user 12 beta'].mean()

plt.subplot(4,2,7)
plt.plot(dc1['user 13 alpha'])
plt.plot(dc1['user 13 beta'])
dc_7_am = dc1['user 13 alpha'].mean()
dc_7_bm = dc1['user 13 beta'].mean()

plt.subplot(4,2,8)
plt.plot(dc1['user 16 alpha'])
plt.plot(dc1['user 16 beta'])
dc_8_am = dc1['user 16 alpha'].mean()
dc_8_bm = dc1['user 16 beta'].mean()

# plt.subplot(5,2,9)
# plt.plot(dc1['user 17 alpha'])
# plt.plot(dc1['user 17 beta'])

plt.tight_layout()
plt.show();

# %% [markdown]
# ### Relaxation Stage

# %%
dr1.describe()
# Out:
#            VAR00001      VAR00002      VAR00003      VAR00004      VAR00005  \
# count  36750.000000  36750.000000  36750.000000  36750.000000  36750.000000
# mean       0.429762      0.428670      0.441281      0.353036      0.325746
# std        0.194635      0.191631      0.180828      0.030780      0.155078
# min        0.158999      0.000000      0.308680      0.218740      0.000000
# 25%        0.302797      0.340350      0.347382      0.341944      0.255947
# 50%        0.357109      0.352998      0.351247      0.357691      0.318082
# 75%        0.457715      0.374623      0.361748      0.367963      0.385509
# max        1.114666      0.864099      0.901367      0.485110      1.037929
#
#            VAR00006      VAR00007      VAR00008      VAR00010      VAR00011  \
# count  36750.000000  36750.000000  36750.000000  36750.000000  36750.000000
# mean       0.354452      0.349529      0.350130      0.351957      0.350610
# std        0.044781      0.080724      0.014338      0.088074      0.019433
# min        0.238819      0.154490      0.292536      0.125173      0.259509
# 25%        0.338573      0.301168      0.342202      0.296270      0.340728
# 50%        0.352082      0.340350      0.349193      0.347704      0.350236
# 75%        0.363718      0.383385      0.355814      0.391972      0.359815
# max        0.797272      0.823077      0.423664      0.858308      0.439178
#
#            VAR00012      VAR00013      VAR00014      VAR00015      VAR00016  \
# count  36750.000000  36750.000000  36750.000000  36750.000000  36750.000000
# mean       0.350233      0.350610      0.361465      0.351184      0.350347
# std        0.077487      0.019433      0.094350      0.032171      0.073968
# min        0.177504      0.259509      0.111624      0.235621      0.161491
# 25%        0.296957      0.340728      0.293818      0.333351      0.304209
# 50%        0.339646      0.350236      0.347526      0.351616      0.342085
# 75%        0.395350      0.359815      0.416878      0.368031      0.386437
# max        0.675772      0.439178      0.785766      0.555311      0.706451
#
#            VAR00017      sumAlpha       sumBeta         Alpha          Beta
# count  36750.000000  36750.000000  36750.000000  36750.000000  36750.000000
# mean       0.350033      2.960321      2.888725      0.370040      0.361091
# std        0.015411      0.349722      0.203153      0.043715      0.025394
# min        0.293787      2.146420      2.290823      0.268303      0.286353
# 25%        0.341064      2.705547      2.775917      0.338193      0.346990
# 50%        0.351090      2.953702      2.817527      0.369212      0.352191
# 75%        0.359345      3.199021      2.915775      0.399877      0.364472
# max        0.410304      4.016205      3.400733      0.502026      0.425092

# %%
plt.figure(figsize=(9,9))

plt.subplot(4,2,1)
plt.plot(dr1['VAR00001'])
plt.plot(dr1['VAR00002'])
dr_1_am = dr1['VAR00001'].mean()
dr_1_bm = dr1['VAR00002'].mean()

plt.subplot(4,2,2)
plt.plot(dr1['VAR00004'])
plt.plot(dr1['VAR00003'])
dr_2_am = dr1['VAR00004'].mean()
dr_2_bm = dr1['VAR00003'].mean()

plt.subplot(4,2,3)
plt.plot(dr1['VAR00005'])
plt.plot(dr1['VAR00004'])
dr_3_am = dr1['VAR00005'].mean()
dr_3_bm = dr1['VAR00004'].mean()

plt.subplot(4,2,4)
plt.plot(dr1['VAR00007'])
plt.plot(dr1['VAR00006'])
dr_4_am = dr1['VAR00007'].mean()
dr_4_bm = dr1['VAR00006'].mean()

plt.subplot(4,2,5)
plt.plot(dr1['VAR00010'])
plt.plot(dr1['VAR00008'])
dr_5_am = dr1['VAR00010'].mean()
dr_5_bm = dr1['VAR00008'].mean()

plt.subplot(4,2,6)
plt.plot(dr1['VAR00012'])
plt.plot(dr1['VAR00011'])
dr_6_am = dr1['VAR00012'].mean()
dr_6_bm = dr1['VAR00011'].mean()

plt.subplot(4,2,7)
plt.plot(dr1['VAR00014'])
plt.plot(dr1['VAR00013'])
dr_7_am = dr1['VAR00014'].mean()
dr_7_bm = dr1['VAR00013'].mean()

plt.subplot(4,2,8)
plt.plot(dr1['VAR00016'])
plt.plot(dr1['VAR00015'])
dr_8_am = dr1['VAR00016'].mean()
dr_8_bm = dr1['VAR00015'].mean()

plt.tight_layout()
plt.show();


fig=plt.figure(figsize=(18, 16), dpi= 150, facecolor='w', edgecolor='k')

# %%
tt_sec = np.arange(len(ct1['SumAlpha'])) / 250.0
tee_sec = np.arange(len(dr1['Alpha'])) / 250.0
te_sec = np.arange(len(dc1['Sum Alpha'])) / 250.0

plt.figure(figsize=(9,9))

plt.subplot(3,1,1)
plt.title("Tutorial (Baseline)")
plt.plot(tt_sec, ct1['SumAlpha'])
plt.plot(tt_sec, ct1['SumBeta'])
plt.xlabel("Time (sec)")     

plt.subplot(3,1,2)
plt.title("Relaxation experiment stage")
plt.plot(tee_sec, dr1['Alpha'])
plt.plot(tee_sec, dr1['Beta'])
plt.xlabel("Time (sec)")       

plt.subplot(3,1,3)
plt.title("Concentration experiment stage")
plt.plot(te_sec, dc1['Sum Alpha'])
plt.plot(te_sec, dc1['Sum Beta'])
plt.xlabel("Time (sec)")       

plt.tight_layout()
plt.show();

# %%
dConcent.ix[0, :]
# dTutorial.ix[2,:]
# dRelax.ix[2,:]
# Out:
# user 2 alpha                   0.349303
# user 2 beta                    0.241697
# user 6 alpha                   0.406634
# user 6 beta                    0.348091
# user 7 alpha                   0.362151
# user 7 beta                    0.338290
# user 8 alpha                   0.386219
# user 8 beta                    0.355083
# user 9 alpha                   0.410847
# user 9 beta                    0.352670
# user 12 alpha                  0.301567
# user 12 beta                   0.351008
# user 13 alpha                  0.308226
# user 13 beta                   0.351008
# user 16 alpha                  0.339044
# user 16 beta                   0.353045
# user 17 alpha                  0.436772
# user 17 beta                   0.368956
# Sum Alpha                      3.300764
# Sum Beta                       2.690890
# sumBeta-                       1.300832
# Alpha waves                    0.366752
# Beta waves                     0.298988
# NonLearnersAlpha               1.616404
# NonLearnersBeta                1.408006
# (NonLearnersAlpha) / 4         0.404101
# (NonLearnersBeta) / 4          0.352002
# LearnersAlpha                  1.684359
# LearnetsBeta                   1.651840
# (LearnetsBeta) / 5             0.330368
# (LearnersAlpha) / 5            0.336872
# LowLearners Alpha over Beta    1.148009
# Learners Alpha over Beta       1.019687
# Name: 0, dtype: float64

# %%
### All users mean alpha perforamnce
all_alpha_Relaxation = (dr_1_am + dr_2_am  + dr_3_am  + dr_4_am  + dr_5_am  + dr_6_am  + dr_7_am + dr_8_am)  / 8
all_beta_Relaxation = (dr_1_bm + dr_2_bm  + dr_3_bm  + dr_4_bm  + dr_5_bm  + dr_6_bm  + dr_7_bm + dr_8_bm)  / 8

all_alpha_Concentration = (dc_1_am + dc_2_am  + dc_3_am  + dc_4_am  + dc_5_am  + dc_6_am  + dc_7_am + dc_8_am)  / 8
all_beta_Concentration = (dc_1_bm + dc_2_bm  + dc_3_bm  + dc_4_bm  + dc_5_bm  + dc_6_bm  + dc_7_bm + dc_8_bm)  / 8

all_alpha_Tutorial = (ct_1_am + ct_2_am  + ct_3_am  + ct_4_am  + ct_5_am  + ct_6_am  + ct_7_am + ct_8_am)  / 8
all_beta_Tutorial = (ct_1_bm + ct_2_bm  + ct_3_bm  + ct_4_bm  + ct_5_bm  + ct_6_bm  + ct_7_bm + ct_8_bm)  / 8

AllUsersID = [1,2,3,4,5,6] #,7,8,9]

LABELS = ["Relaxation Alpha", "Relaxation Beta", "User 3", "User 4", "User 5", "User 6"] #, "User 7", "User 8", "User 9"]
bRelaxation = [all_alpha_Tutorial,all_beta_Tutorial, all_alpha_Relaxation, all_beta_Relaxation, all_alpha_Concentration, all_beta_Concentration ];

plt.bar(AllUsersID, bRelaxation, align='center')
plt.xticks(AllUsersID, LABELS)
plt.show()

# %%
from scipy.stats import ttest_1samp, ttest_ind, wilcoxon, mannwhitneyu

t_stat, p_value = ttest_ind(all_alpha_Tutorial, all_beta_Tutorial)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-58f8249b0aaa> in <module>()
#       1 from scipy.stats import ttest_1samp, ttest_ind, wilcoxon, mannwhitneyu
#       2
# ----> 3 t_stat, p_value = ttest_ind(all_alpha_Tutorial, all_beta_Tutorial)
#
# /usr/lib/python2.7/dist-packages/scipy/stats/stats.pyc in ttest_ind(a, b, axis, equal_var)
#    3290     """
#    3291     a, b, axis = _chk2_asarray(a, b, axis)
# -> 3292     v1 = np.var(a, axis, ddof=1)
#    3293     v2 = np.var(b, axis, ddof=1)
#    3294     n1 = a.shape[axis]
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.pyc in var(a, axis, dtype, out, ddof, keepdims)
#    2928
#    2929     return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# -> 2930                                 keepdims=keepdims)
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _var(a, axis, dtype, out, ddof, keepdims)
#      78     arr = asanyarray(a)
#      79
# ---> 80     rcount = _count_reduce_items(arr, axis)
#      81     # Make this warning show up on top.
#      82     if ddof >= rcount:
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _count_reduce_items(arr, axis)
#      48     items = 1
#      49     for ax in axis:
# ---> 50         items *= arr.shape[ax]
#      51     return items
#      52
#
# IndexError: tuple index out of range

# %%
# meanRSP = [ .468652, 0.309182, 0.325133,0.260310,0.431099, 0.390164,0.284937,0.335882,0.346200, 0.305813, 0.362405, 0.464674,0.864277,0.336622, 0.353641,0.353641,0.317855,0.346788]

# meanRSP = [
# [0.468652, 0.305813 ],
# [0.309182, 0.362405 ],
# [0.325133, 0.464674 ],
# [0.260310, 0.864277 ],
# [0.431099, 0.336622 ],
# [0.390164, 0.353641 ],
# [0.284937, 0.353641 ],
# [0.335882, 0.317855 ],
# [0.346200, 0.346788 ] ];

# #all sampled users
# print(meanRSP);

# N = 9;
# width = 1/1.5
# x = range(N)

# plt.bar(AllUsersID, meanRSP[2,:]);


lapply(names(testData)[-1],function(x)
           t.test(as.formula(paste(x,"Label",sep="~")),
                  data=testData))
# Out:
#   File "<ipython-input-18-863cdbe1eed9>", line 25
#     t.test(as.formula(paste(x,"Label",sep="~")),
#     ^
# SyntaxError: invalid syntax

# %%
meanRSP_girls_alpha = [
        [ 0.325133 ],
        [ 0.26031  ],
        [ 0.335882 ],
        [ 0.346    ],
        [ 0.346200   ]
];

plt.plot(meanRSP_girls_alpha, color='red');
meanRSP_girls_beta = [
        [ 0.464674 ],
        [ 0.864277 ],
        [ 0.317855 ],
        [ 0.346788 ],
        [ 0.317855 ]
];
plt.plot(meanRSP_girls_beta, color='#85144b');

meanRSP_guys_alpha = [
        [ 0.468652],
        [ 0.309182],
        [ 0.431099],
        [ 0.390164],
        [ 0.284937]
];
plt.plot(meanRSP_guys_alpha, color='#0074D9');

meanRSP_guys_beta = [
        [ 0.305813 ],
        [ 0.362405 ],
        [ 0.336622 ],
        [ 0.353641 ],
        [ 0.353641 ]
];

plt.plot(meanRSP_guys_beta, color='#001f3f');

# %%
plt.scatter(meanRSP_guys_alpha,meanRSP_guys_beta)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-480b6788f7e7> in <module>()
# ----> 1 print(meanRSP_girls[:,1].mean());
#       2 print(meanRSP_guys[:,1].mean());
#
# NameError: name 'meanRSP_girls' is not defined

# %%
# Experiment Stages
